# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniaannaan/ObliczeniaNaukowe/blob/main/zadDomowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Obliczenia naukowe 1 zadanie domowa

# %% [markdown]
# # Sekcja pierwsza

# %%
imie = input("Jak sie nazywasz?")
print("Hi", imie)
# Out:
# Jak sie nazywasz?Anna
# Hi Anna

# %% [markdown]
# # Sekcja druga

# %% [markdown]
# ```
# imie = input("Jak sie nazywasz?")
# print("Hi", imie)
# ```

# %% [markdown]
# # Sekcja trzecia

# %% [markdown]
# ![puszek.jpg](data:image/jpeg;base64,...)
