# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniaannaan/ObliczeniaNaukowe/blob/main/Lab8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Wykresy 3d

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
fig=plt.figure()
ax1=fig.add_subplot(projection='3d')

# %%
# %matplotlib inline
from mpl_toolkits import mplot3d
import numpy as np

# %%
x=np.linspace(0,1,100)
y=np.linspace(0,1,100)
z=x*y
fig=plt.figure()
ax1=fig.add_subplot(121,projection='3d')
ax1.plot(x,y,z)
ax2=fig.add_subplot(122)
ax2.plot(x,y,z)

# %%
fig,ax=plt.subplots()
theta=np.linspace(0,7,100)
x=np.cos(theta)
y=np.sin(theta)
ax.plot(x,y)

# %%
fig,ax=plt.subplots()
t=np.linspace(0,50,100)
R=3000
r=500
x=(R-r)*np.cos(t)+r*np.cos((R-r)/r*t)
y=(R-r)*np.sin(t)-r*np.sin((R-r)/r*t)
ax.plot(x,y)
